# %% [markdown]
# # Trabalho #2 - Classificação binária com rede neural deep-learning
#
# Nesse trabalho você vai desenvolver uma rede neural rasa e uma deep-learning, usando a plataforma TensorFlow-Keras, para realizar uma tarefa de classificação binária para reconhecer gatos em imagens e comparar o desempenho das duas redes.

# %% [markdown]
# ## Identificação
#
# Nome:

# %% [markdown]
# ## 1 - Bibliotecas ##
#
# Em primeiro lugar, execute a célula abaixo para importar algumas bibliotecas Python que são usadas nesse trabalho.
# - [numpy](www.numpy.org) é a biblioteca básica para computação cinetífica usando Python.
# - [h5py](http://www.h5py.org) é uma biblioteca que fornece funções para interagir com banco de dados salvos em arquivos no formato h5.
# - [matplotlib](http://matplotlib.org) é uma biblioteca famosa usada para fazer gráficos com Python.
# - [PIL](http://www.pythonware.com/products/pil/) e [scipy](https://www.scipy.org/) são usadas para testar a sua RNA com novas imagens no final do trabalho.
# - lr_utils é um arquivo com uma função para ler os dados usados nesse trabalho.

# %% [markdown]
# O comando da célula abaixo importa o TensorFlow e verifica a versão que está sendo utilizada.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.17.0'

# %% [markdown]
# Como o TensorFlow é um software aberto não existe muita preocupação do desenvolvedor (no caso o Google) de manter a compatibilidade entre as versões. Assim, se você estiver usando uma versão do TensorFlow incompatível com o seu programa, você pode impor o uso de uma versão mais antiga.
#
# Por exemplo o código abaixo importa a versão 2 do TensorFlow, mas se ela não estiver instalada importa a versão instalada.
#
# ```
#  try:
#      import tensorflow.compat.v2 as tf
#  except Exception:
#      import tensorflow as tf
#  print(tf.__version__)
# ```
#
# Outro exemplo, se a versão instalada do TensorFlow for a 2 e o seu programa foi feito para a versão 1, então pode habilitar a versão 2 com o comportamento da versão 1. O código abaixo mostra como fazer isso.
#
# ```
#  import tensorflow as tf
#  print(tf.__version__)
#  tf.enable_v1_behavior()
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import scipy
from PIL import Image
from scipy import ndimage

# %matplotlib inline

# %% [markdown]
# ## 2 - Visão geral do problema ##
#
# **Definição do problema**:
#
# Nesse trabalho é fornecido um conjunto de dados que contém:
#
#     - um conjunto de imagens de treinamento classificadas como tendo gato (y=1) ou não tendo gato (y=0);
#     - um conjunto de imagens de teste classificadas como tendo gato (y=1) ou não tendo gato (y=0);
#     - a dimensão de cada imagem é (num_px, num_px, 3), onde 3 é o número de canais de cor (RGB);
#     - cada imagem é composta por três matrizes de dimensão: número de linhas = num_px e número de colunas = num_px;
#     - número de imagens do conjunto de treinamento: m_train;
#     - número de imagens do conjunto de teste: m_test.
#
# A partir desses conjuntos de dados, a sua tarefa é desenvolver um sistema baseado em uma rede neural, para processar imagens e classificar corretamente se ela mostra ou não um gato. Para isso, você vai desenvolver algumas redes neurais usando a ferramenta Keras e comparar o desempenho delas.
#
# O uso da ferramenta Keras para desenvolver redes neurais facilita muito o trabalho, pois não exige desenvolver codigos específicos para implementar cada camada da rede, a função de custo, a métrica e principalmente o gradiente descendente.

# %% [markdown]
# ## 3 - Conjunto de dados de treinamento e teste
#
# O conjunto de dados utilizado pode ser obtido em: https://www.kaggle.com/mriganksingh/cat-images-dataset. Para carregar esse conjunto de dados execute o código a seguir.
#
# O termo _orig é adicionado no final dos tensores com os dados de treinamento e teste originais porque vamos processar esses dados.

# %%
# Conjunto de dados de treinamento
train_dataset = h5py.File('train_catvnoncat.h5', "r")
train_set_x_orig = np.array(train_dataset["train_set_x"][:]) 
train_set_y = np.array(train_dataset["train_set_y"][:]) 

# Conjunto de dados de teste
test_dataset = h5py.File('test_catvnoncat.h5', "r")
test_set_x_orig = np.array(test_dataset["test_set_x"][:])
test_set_y = np.array(test_dataset["test_set_y"][:]) 

# Acerta dimensões das saídas
train_set_y = train_set_y.reshape((1, train_set_y.shape[0]))
test_set_y = test_set_y.reshape((1, test_set_y.shape[0]))
    
classes = np.array(test_dataset["list_classes"][:]) # the list of classes

# %%
# Examplo de uma imagem
index = 11
print(train_set_x_orig[index].shape)
plt.imshow(train_set_x_orig[index])
print ("y = " + str(train_set_y[:, index]) + ", it's a '" + classes[np.squeeze(train_set_y[:, index])].decode("utf-8") +  "' picture.")
# Out:
# (64, 64, 3)
# y = [1], it's a 'cat' picture.

# %% [markdown]
# No código acima index é o número sequencial da imagem. Tente trocar a imagem, mudando o index, usando valores entre 0 e 208, para visualizar outros exemplos.

# %% [markdown]
# ### 3.1 - Determinação do formato e dimensões dos dados
#
# ### Exercício #1:
#
# É importante conhecer as dimensões dos dados que estamos trabalhando para evitar problemas. Assim, obtenha os valores dos seguintes parâmetros:
#     - m_train = número de exemplos de treinamento;
#     - m_test = número de exemplos de teste;
#     - num_px = altura e largura das imagens (as imagens são quadradas).
#
# Lembre que `train_set_x_orig` é um tensor numpy de dimensão (m_train, num_px, num_px, 3). Por exemplo, você pode obter  `m_train` escrevendo `train_set_x_orig.shape[0]`.

# %%
# PARA VOCÊ FAZER:

### COMECE AQUIE ### (≈ 3 linhas)
m_train = train_set_x_orig.shape[0]
m_test = test_set_x_orig.shape[0]
num_px = train_set_x_orig.shape[1]
### TERMINE AQUI ###

print ("Número de exemplos de treinamento: m_train = " + str(m_train))
print ("Número de exemplos de teste: m_test = " + str(m_test))
print ("Altura/largura de cada imagem: num_px = " + str(num_px))
print ("Dimensão de cada imagem: (" + str(num_px) + ", " + str(num_px) + ", 3)")
print ("Dimensão - train_set_x: " + str(train_set_x_orig.shape))
print ("Dimensão - train_set_y: " + str(train_set_y.shape))
print ("Dimensão - test_set_x: " + str(test_set_x_orig.shape))
print ("Dimensão - test_set_y: " + str(test_set_y.shape))
# Out:
# Número de exemplos de treinamento: m_train = 209
# Número de exemplos de teste: m_test = 50
# Altura/largura de cada imagem: num_px = 64
# Dimensão de cada imagem: (64, 64, 3)
# Dimensão - train_set_x: (209, 64, 64, 3)
# Dimensão - train_set_y: (1, 209)
# Dimensão - test_set_x: (50, 64, 64, 3)
# Dimensão - test_set_y: (1, 50)

# %% [markdown]
# **Saída esperada para m_train, m_test e num_px**:
#
#     Número de exemplos de treinamento: m_train = 209
#     Número de exemplos de teste: m_test = 50
#     Altura/largura de cada imagem: num_px = 64
#     Dimensão de cada imagem: (64, 64, 3)
#     Dimensão - train_set_x: (209, 64, 64, 3)
#     Dimensão - train_set_y: (1, 209)
#     Dimensão - test_set_x: (50, 64, 64, 3)
#     >Dimensão - test_set_y: (1, 50)
#
# Observe que o primeiro eixo dos tensores com as imagens dos conjuntos de teste e de treinamento representa os exemplos, da forma como é esperado para os dados no Keras.

# %% [markdown]
# ### 3.2 - Processamento dos dados
#
# Os dados dos exemplos de treinamento e de teste devem ser processados de forma a serem colocados em tensores com as dimensões adequadas e normalizados corretamente. Nos exercícios que seguem você irá realizar o processamento dos dados de forma a poderem ser usados na sua RNA implementada com o Keras.

# %% [markdown]
# ### Redimensionamento dos dados
#
# Os dados de entrada de uma camada de neurônios densa é um vetor, assim, devemos redimensionar as imagens, que tem dimensão (num_px, num_px, 3), para transformá-las em um vetor linha de dimensão (1, num_px∗num_px∗3). Após esse redimensionamento o conjunto de dados é um tensor numpy onde cada linha representa uma imagem "esticada". O tensor com as entradas dos dados de treinamento terá m_train linhas e o de teste m_test linhas.
#
# Por exemplo, para redimensionar uma matriz de dimensão (a,b,c,d) para uma matriz de dimensão (a, b∗c∗d) pode-se usar o seguinte código Python:
#
#     X_flatten = X.reshape((a, b∗c∗d))
#
# A dimensão dos dados de saída também deve ser alterada porque, como visto, o Keras espara que os exemplos representam o primeiro eixo do tensor e nos dados de saída os exemplos representam o segundo eixo. Assim, os vetores com os dados de saída, tanto de treinamento como de teste, devem ser transpostos.

# %% [markdown]
# ### Exercício #2:
#
# Implemente o redimensionamento dos dados de entrada na célula a seguir.

# %%
# PARA VOCÊ FAZER: redimensionamento das imagens dos exemplos de treinamento e teste

### COMECE AQUI ### (≈ 2 linhas)
# Redimensionamento dos dados de entrada
train_set_x_flatten = train_set_x_orig.reshape(train_set_x_orig.shape[0], -1)
test_set_x_flatten = test_set_x_orig.reshape(test_set_x_orig.shape[0], -1)
### TERMINE AQUI ###

### COMECE AQUI ### (≈ 2 linhas)
# Redimensionamento dos dados de saída (transposição)
train_set_y = train_set_y.T
test_set_y = test_set_y.T
### TERMINE AQUI ###

print ("Dimensão - train_set_x_flatten: " + str(train_set_x_flatten.shape))
print ("Dimensão - train_set_y: " + str(train_set_y.shape))
print ("Dimensão - test_set_x_flatten: " + str(test_set_x_flatten.shape))
print ("Dimensão - test_set_y: " + str(test_set_y.shape))
print ("Verificação de valores após redimensionamento: " + str(train_set_x_flatten[0,0:5]))
# Out:
# Dimensão - train_set_x_flatten: (209, 12288)
# Dimensão - train_set_y: (209, 1)
# Dimensão - test_set_x_flatten: (50, 12288)
# Dimensão - test_set_y: (50, 1)
# Verificação de valores após redimensionamento: [17 31 56 22 33]

# %% [markdown]
# **Saída esperada**:
#
#     Dimensão - train_set_x_flatten: (209, 12288)
#     Dimensão - train_set_y: (209, 1)
#     Dimensão - test_set_x_flatten: (50, 12288)
#     Dimensão - test_set_y: (50, 1)
#     Verificação de valores após redimensionamento: [17 31 56 22 33]

# %% [markdown]
# ### Normalização dos dados
#
# Nas imagens coloridas as cores vermelho, verde e azul (RGB) são especificadas para cada pixel da imagem, de forma que cada pixel consite de um vetor de tres números que variam no intervalo de 0 a 255.
#
# Uma etapa do processamento dos dados é normalizar esses dados de forma a ter dados com média zero e desvio padrão um. No caso de imagens o processo de normalização dos dados é mais simples e consiste simplesmente em dividir todos os valores da imagem por 255, que é o valor máximo de um pixel.
#
# ### Exercício #3:
#
# Implemente a normalização dos dados de forma a ter todas os elementos dos dados de entrada entre 0 e 1.

# %%
# PARA VOCÊ FAZER: redimensionamento das imagens dos exemplos de treinamento e teste

### COMECE AQUI ### (≈ 2 linhas)
train_set_x = train_set_x_flatten/255.
test_set_x = test_set_x_flatten/255.
### TERMINE AQUI ###

print ("Máximo valor de train_set_x: " + str(np.max(train_set_x)))
print ("Máximo valor de train_set_x: " + str(np.max(test_set_x)))
# Out:
# Máximo valor de train_set_x: 1.0
# Máximo valor de train_set_x: 1.0

# %% [markdown]
# **Saída esperada**:
#
#     Máximo valor de train_set_x: 1.0
#     Máximo valor de train_set_x: 1.0

# %% [markdown]
# <font color='blue'>
#
# **O que é importante lembrar:**
#
# As etapas principais do processamento de dados são as seguintes:
# - Verificar a dimensão e formato dos dados do problema. Nesse caso são: m_train, m_test, num_px, ...
# - Redimensionar os conjuntos de dados. Nesse caso para cada exemplo a entrada é um vetor linha de dimensão (1, num_px \* num_px \* 3)
# - Normalizar os dados

# %% [markdown]
# ## 4 - Desenvolvimento e teste da rede neural rasa
#
# Nesse trabalho vamos testar diferentes redes neurais, variando numero de camadas, numero de neurônios nas camadas e tipo de função de ativação para obtermos uma solução que apresente resultados satisfatórios.
#
# Conforme vimos em aula, o desenvolvimento de uma RNA com o Keras é feito segundo as seguintes etapas:
#
# 1. Definição dos dados de treinamento e de teste;
# 2. Configuração da RNA;
# 3. Compilação da RNA, que também inclui a configuração do processo de treinamento pela escolha da função de custo, do otimizador e da métrica para avaliar o desempenho;
# 4. Treinamento da RNA;
# 5. Teste e avaliação do desempenho da RNA.
#
# Observe que a etapa de definição e preparação dos dados já foi realizada.

# %% [markdown]
# ### 4.1 - Configuração da rede neural ##
#
# Vamos configurar, treinar e testar uma primeira rede neural simples de uma camada intermediária usando o Keras.
#
# Para essa rede de uma camada, o parâmetro mais importante é o número de neurônios da camada intermediária. Esse número deve ser compatível com o problema que queremos resolver e também com o número de exemplos que temos disponíveis para treinar a rede.
#
# Em linhas gerais cada imagem é representada por 12.288 números e temos 209 imagens de treinamento. Assim, no conjunto de dados de treinamento temos cerca de 2,6 milhões de valores. Existem um princípio em aprendizado supervisionado que diz que o número de parâmetros do sistema deve ser menor do que o número de valores presente no conjunto de dados utilizado para o treinamento. Assim, a sua rede neural deve ter um número de parâmetros menor do que 2,6 milhões. Se a rede possuir mais parâmetros do que o número de valores presentes no conjunto de dados, ela simplesmente memoriza os dados de treinamento e não funciona direito para nenhum outro caso.
#
# **Qualquer dúvida que você possa ter de como fazer esse trabalho usando o Keras, consulte os slides e o notebook da aula no Moodle**
#
# ### Exercício #4:
#
# Usando o Keras configure uma rede neural com as seguintes caracteríticas:
#
# - uma única camada intermediária com 64 neurônios e função de ativação sigmóide;
# - como queremos resolver um problema de classificação binária a camada de saída deve possuir um único neurônio e ter função de ativação sigmóide.

# %%
# PARA VOCÊ FAZER: configuração de uma RNA rasa

# Importar do Keras classes de modelos e camadas 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

np.random.seed(1) # inicializa gerador de números aleatórios

# Configuração da rede
### COMECE AQUI ### (≈ 3 linhas)
rna = Sequential()
rna.add(Dense(64, input_dim = num_px*num_px*3, activation='relu'))
rna.add(Dense(1, activation='sigmoid'))
### TERMINE AQUI ###

# Visualização da rede
rna.summary()
# Out:
# /home/codespace/.local/share/virtualenvs/T2_Classificação_binaria_keras-L9rped1J/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 64)             │       786,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 786,561 (3.00 MB)
#  Trainable params: 786,561 (3.00 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Saída esperada:**
#
#     Model: "sequential"
#     _________________________________________________________________
#     Layer (type)                 Output Shape              Param #
#     =================================================================
#     dense (Dense)                (None, 64)                786496
#     _________________________________________________________________
#     dense_1 (Dense)              (None, 1)                 65
#     =================================================================
#     Total params: 786,561
#     Trainable params: 786,561
#     Non-trainable params: 0
#     _________________________________________________________________

# %% [markdown]
# ### 4.2 - Compilação e treinamento da rede neural
#
# A segunda e terceira etapas de desenvolvimento da rede no Keras é a sua compilação e treinamento.
#
# ### Exercício #5:
#
# Compile e treine a sua rede neural usando as seguintes opções:
#
# - Método de otimização: gradiente descendente;
# - Função de custo: entropia cruzada;
# - Métrica: exatidão;
# - No treinamento, utilize no método fit o parâmetro batch_size=209, que é o número de exemplos de treinamento;
# - Número de épocas: 10.
#
# Nesse momento estamos treinando a rede somente para verificar se ela é adequada para resolver o problema e se está configurada de forma correta, por isso usamos poucas épocas de treinamento.
#
# Note que para o Keras, certos parâmetros podem ser definidos de formas distintas. Por exemplo, a métrica "Mean Absolute Error" pode ser definida como keras.metrics.MeanAbsoluteError() ou simplesmente pelo string 'mae'.

# %%
# PARA VOCÊ FAZER: configuração do otimizador e treinamento da RNA rasa

# Importar do Keras classe de otimizadores
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics

# Compilação da rede 
### COMECE AQUI ### (≈ 1 ou 2 linhas)
rna.compile(optimizer=optimizers.SGD(learning_rate=0.01), loss='binary_crossentropy', metrics=['accuracy'])
### TERMINE AQUI ###

# Teste de treinamento da rede
### COMECE AQUI ### (≈ 1 linha)
rna.fit(train_set_x, train_set_y, epochs=10, batch_size=209)
### TERMINE AQUI ###
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 652ms/step - accuracy: 0.4019 - loss: 0.7543
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6555 - loss: 1.0095
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.5263 - loss: 0.6924
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6555 - loss: 0.6557
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.6507 - loss: 0.6398
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.6459 - loss: 0.6328
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.6459 - loss: 0.6267
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.6507 - loss: 0.6217
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6507 - loss: 0.6176
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.6507 - loss: 0.6133

# %% [markdown]
# **Saída esperada:**
#
#     Epoch 1/10
#     209/209 [==============================] - 0s 1ms/sample - loss: 0.7257 - acc: 0.3876
#     Epoch 2/10
#     209/209 [==============================] - 0s 272us/sample - loss: 0.6633 - acc: 0.6555
#     Epoch 3/10
#     209/209 [==============================] - 0s 162us/sample - loss: 0.6539 - acc: 0.6459
#     Epoch 4/10
#     209/209 [==============================] - 0s 153us/sample - loss: 0.6515 - acc: 0.6507
#     Epoch 5/10
#     209/209 [==============================] - 0s 153us/sample - loss: 0.6502 - acc: 0.6507
#     Epoch 6/10
#     209/209 [==============================] - 0s 143us/sample - loss: 0.6491 - acc: 0.6507
#     Epoch 7/10
#     209/209 [==============================] - 0s 153us/sample - loss: 0.6481 - acc: 0.6507
#     Epoch 8/10
#     209/209 [==============================] - 0s 166us/sample - loss: 0.6471 - acc: 0.6507
#     Epoch 9/10
#     209/209 [==============================] - 0s 157us/sample - loss: 0.6461 - acc: 0.6507
#     Epoch 10/10
#     209/209 [==============================] - 0s 167us/sample - loss: 0.6451 - acc: 0.6507
#
# Se o seu resultado é esse ou parecido com esse, você pode conluir que a rede está correta e é capaz de aprender os dados de treinamento. Assim, agora você está pronto para treinar a rede de verdade.
#
# Atenção: É normal que os valores sejam ligeiramente diferentes nesta etapa. Mesmo com seeds aleatórios fixos, algumas etapas do treinamento podem não ser completamente determinísticas.

# %% [markdown]
# ### Exercício #6:
#
# Retreine a sua rede usando 1000 épocas.
#
# Use a opção de **não imprimir** os resultados parciais do treinamento para não gerar tantos dados. No Keras podemos escolher como monitoramos o progresso do treinamento com o parâmetro verbose do método fit, que nos dá as seguintes opções:
#
# - verbose: inteiro = 0, 1, or 2.
# - verbose = 0: silencioso;
# - verbose = 1; barra de progresso (padrão);
# - verbose = 2; uma linha por época.
#
# Guarde os resultados do treinamento para poder fazer um gráfico do processo de treinamento. Se tiver dúvidas, veja no notebook desenvolvido em aula como fazer isso.
#
# Não se esqueça de usar no método fit o parâmetro batch_size=209.
#
# Esse treinamento pode levar alguns minutos. No Google Colab levou cerca de 30 segundossem uso de GPU, mas pode variar dependendo de detalhes da implementação e da carga nos servidores do Colab

# %%
# PARA VOCÊ FAZER: treinamento da RNA por 1000 épocas

### COMECE AQUI ### (≈ 1 linha)
history = rna.fit(train_set_x, train_set_y, epochs=1000, batch_size=209)
### TERMINE AQUI ###
# Out:
# Epoch 1/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6507 - loss: 0.6095
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6507 - loss: 0.6059
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6507 - loss: 0.6025
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6507 - loss: 0.5993
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.6603 - loss: 0.5962
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6603 - loss: 0.5932
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6651 - loss: 0.5902
# Epoch 8/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.6699 - loss: 0.5870
# Epoch 9/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6746 - loss: 0.5834
# Epoch 10/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.6699 - loss: 0.5809
# Epoch 11/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.6842 - loss: 0.5786
# Epoch 12/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6699 - loss: 0.5760
# Epoch 13/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7129 - loss: 0.5737
# Epoch 14/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6699 - loss: 0.5726
# Epoch 15/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7464 - loss: 0.5718
# Epoch 16/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6699 - loss: 0.5723
# Epoch 17/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7799 - loss: 0.5724
# Epoch 18/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6699 - loss: 0.5742
# Epoch 19/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7990 - loss: 0.5740
# Epoch 20/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6699 - loss: 0.5741
# Epoch 21/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7943 - loss: 0.5714
# Epoch 22/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6699 - loss: 0.5686
# Epoch 23/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8182 - loss: 0.5644
# Epoch 24/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6699 - loss: 0.5588
# Epoch 25/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8134 - loss: 0.5546
# Epoch 26/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6699 - loss: 0.5531
# Epoch 27/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8182 - loss: 0.5520
# Epoch 28/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6699 - loss: 0.5511
# Epoch 29/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8134 - loss: 0.5502
# Epoch 30/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6699 - loss: 0.5494
# Epoch 31/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8182 - loss: 0.5488
# Epoch 32/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6699 - loss: 0.5466
# Epoch 33/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8278 - loss: 0.5431
# Epoch 34/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6746 - loss: 0.5417
# Epoch 35/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8278 - loss: 0.5403
# Epoch 36/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6699 - loss: 0.5406
# Epoch 37/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8182 - loss: 0.5384
# Epoch 38/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6746 - loss: 0.5364
# Epoch 39/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8230 - loss: 0.5344
# Epoch 40/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6746 - loss: 0.5344
# Epoch 41/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8182 - loss: 0.5331
# Epoch 42/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6746 - loss: 0.5321
# Epoch 43/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8230 - loss: 0.5301
# Epoch 44/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6746 - loss: 0.5297
# Epoch 45/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8278 - loss: 0.5283
# Epoch 46/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6746 - loss: 0.5286
# Epoch 47/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8230 - loss: 0.5269
# Epoch 48/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6794 - loss: 0.5239
# Epoch 49/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8325 - loss: 0.5202
# Epoch 50/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6986 - loss: 0.5185
# Epoch 51/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8278 - loss: 0.5179
# Epoch 52/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6842 - loss: 0.5187
# Epoch 53/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8469 - loss: 0.5158
# Epoch 54/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7081 - loss: 0.5134
# Epoch 55/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8373 - loss: 0.5115
# Epoch 56/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7129 - loss: 0.5108
# Epoch 57/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8421 - loss: 0.5093
# Epoch 58/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.7033 - loss: 0.5117
# Epoch 59/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8325 - loss: 0.5123
# Epoch 60/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6986 - loss: 0.5128
# Epoch 61/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8325 - loss: 0.5080
# Epoch 62/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7081 - loss: 0.5057
# Epoch 63/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8278 - loss: 0.5040
# Epoch 64/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7177 - loss: 0.5022
# Epoch 65/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8325 - loss: 0.5000
# Epoch 66/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7129 - loss: 0.5022
# Epoch 67/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8373 - loss: 0.5043
# Epoch 68/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7081 - loss: 0.5034
# Epoch 69/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8373 - loss: 0.4992
# Epoch 70/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7273 - loss: 0.4934
# Epoch 71/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8469 - loss: 0.4923
# Epoch 72/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7225 - loss: 0.4932
# Epoch 73/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8421 - loss: 0.4920
# Epoch 74/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7225 - loss: 0.4918
# Epoch 75/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8517 - loss: 0.4935
# Epoch 76/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7177 - loss: 0.4943
# Epoch 77/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8421 - loss: 0.4911
# Epoch 78/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7225 - loss: 0.4870
# Epoch 79/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8517 - loss: 0.4881
# Epoch 80/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7177 - loss: 0.4906
# Epoch 81/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8421 - loss: 0.4887
# Epoch 82/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7321 - loss: 0.4838
# Epoch 83/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8612 - loss: 0.4811
# Epoch 84/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7273 - loss: 0.4805
# Epoch 85/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8421 - loss: 0.4799
# Epoch 86/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7321 - loss: 0.4821
# Epoch 87/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8373 - loss: 0.4832
# Epoch 88/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7225 - loss: 0.4857
# Epoch 89/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8469 - loss: 0.4819
# Epoch 90/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7368 - loss: 0.4727
# Epoch 91/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8660 - loss: 0.4685
# Epoch 92/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.7321 - loss: 0.4705
# Epoch 93/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8469 - loss: 0.4739
# Epoch 94/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7368 - loss: 0.4733
# Epoch 95/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8517 - loss: 0.4719
# Epoch 96/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7321 - loss: 0.4727
# Epoch 97/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8517 - loss: 0.4718
# Epoch 98/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7368 - loss: 0.4675
# Epoch 99/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8660 - loss: 0.4643
# Epoch 100/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7321 - loss: 0.4640
# Epoch 101/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8565 - loss: 0.4647
# Epoch 102/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7368 - loss: 0.4647
# Epoch 103/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8517 - loss: 0.4658
# Epoch 104/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7321 - loss: 0.4660
# Epoch 105/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8565 - loss: 0.4599
# Epoch 106/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7368 - loss: 0.4606
# Epoch 107/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8612 - loss: 0.4575
# Epoch 108/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7321 - loss: 0.4602
# Epoch 109/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8565 - loss: 0.4582
# Epoch 110/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7368 - loss: 0.4585
# Epoch 111/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8612 - loss: 0.4553
# Epoch 112/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7368 - loss: 0.4531
# Epoch 113/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8708 - loss: 0.4482
# Epoch 114/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7416 - loss: 0.4525
# Epoch 115/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8612 - loss: 0.4499
# Epoch 116/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7368 - loss: 0.4545
# Epoch 117/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8565 - loss: 0.4557
# Epoch 118/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7368 - loss: 0.4486
# Epoch 119/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8756 - loss: 0.4369
# Epoch 120/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7656 - loss: 0.4338
# Epoch 121/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8612 - loss: 0.4408
# Epoch 122/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7368 - loss: 0.4456
# Epoch 123/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8612 - loss: 0.4446
# Epoch 124/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7464 - loss: 0.4411
# Epoch 125/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8660 - loss: 0.4363
# Epoch 126/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7560 - loss: 0.4338
# Epoch 127/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8708 - loss: 0.4344
# Epoch 128/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7512 - loss: 0.4364
# Epoch 129/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8660 - loss: 0.4365
# Epoch 130/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7560 - loss: 0.4370
# Epoch 131/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8660 - loss: 0.4368
# Epoch 132/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7560 - loss: 0.4300
# Epoch 133/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8900 - loss: 0.4187
# Epoch 134/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7703 - loss: 0.4224
# Epoch 135/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8708 - loss: 0.4281
# Epoch 136/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7560 - loss: 0.4332
# Epoch 137/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8756 - loss: 0.4291
# Epoch 138/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7608 - loss: 0.4299
# Epoch 139/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8708 - loss: 0.4266
# Epoch 140/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7656 - loss: 0.4246
# Epoch 141/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8852 - loss: 0.4152
# Epoch 142/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7703 - loss: 0.4207
# Epoch 143/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8708 - loss: 0.4222
# Epoch 144/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7703 - loss: 0.4237
# Epoch 145/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8756 - loss: 0.4184
# Epoch 146/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7703 - loss: 0.4206
# Epoch 147/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8708 - loss: 0.4185
# Epoch 148/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7751 - loss: 0.4147
# Epoch 149/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8804 - loss: 0.4126
# Epoch 150/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7656 - loss: 0.4189
# Epoch 151/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8756 - loss: 0.4184
# Epoch 152/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7751 - loss: 0.4165
# Epoch 153/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8804 - loss: 0.4102
# Epoch 154/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7751 - loss: 0.4135
# Epoch 155/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8756 - loss: 0.4070
# Epoch 156/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7751 - loss: 0.4074
# Epoch 157/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8852 - loss: 0.4070
# Epoch 158/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7703 - loss: 0.4159
# Epoch 159/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8756 - loss: 0.4131
# Epoch 160/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7751 - loss: 0.4072
# Epoch 161/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8804 - loss: 0.3976
# Epoch 162/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7751 - loss: 0.4026
# Epoch 163/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8852 - loss: 0.4007
# Epoch 164/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7751 - loss: 0.4024
# Epoch 165/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8900 - loss: 0.4029
# Epoch 166/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7751 - loss: 0.4004
# Epoch 167/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8852 - loss: 0.3937
# Epoch 168/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7847 - loss: 0.3917
# Epoch 169/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8900 - loss: 0.3880
# Epoch 170/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7847 - loss: 0.3907
# Epoch 171/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8947 - loss: 0.3934
# Epoch 172/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7799 - loss: 0.3948
# Epoch 173/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8947 - loss: 0.3900
# Epoch 174/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7847 - loss: 0.3878
# Epoch 175/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8947 - loss: 0.3849
# Epoch 176/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7847 - loss: 0.3843
# Epoch 177/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8947 - loss: 0.3853
# Epoch 178/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7847 - loss: 0.3874
# Epoch 179/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8947 - loss: 0.3848
# Epoch 180/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7847 - loss: 0.3828
# Epoch 181/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8995 - loss: 0.3775
# Epoch 182/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7895 - loss: 0.3765
# Epoch 183/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8947 - loss: 0.3761
# Epoch 184/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.7847 - loss: 0.3771
# Epoch 185/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8947 - loss: 0.3803
# Epoch 186/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7847 - loss: 0.3812
# Epoch 187/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8947 - loss: 0.3739
# Epoch 188/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7847 - loss: 0.3774
# Epoch 189/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8947 - loss: 0.3751
# Epoch 190/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7847 - loss: 0.3781
# Epoch 191/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8947 - loss: 0.3710
# Epoch 192/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7847 - loss: 0.3757
# Epoch 193/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8947 - loss: 0.3729
# Epoch 194/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7847 - loss: 0.3745
# Epoch 195/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8947 - loss: 0.3671
# Epoch 196/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7895 - loss: 0.3680
# Epoch 197/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8947 - loss: 0.3667
# Epoch 198/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7943 - loss: 0.3686
# Epoch 199/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8947 - loss: 0.3629
# Epoch 200/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7943 - loss: 0.3644
# Epoch 201/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8947 - loss: 0.3655
# Epoch 202/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7943 - loss: 0.3680
# Epoch 203/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8947 - loss: 0.3640
# Epoch 204/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8038 - loss: 0.3603
# Epoch 205/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9043 - loss: 0.3545
# Epoch 206/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8086 - loss: 0.3563
# Epoch 207/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8947 - loss: 0.3526
# Epoch 208/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8134 - loss: 0.3551
# Epoch 209/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8947 - loss: 0.3583
# Epoch 210/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7990 - loss: 0.3604
# Epoch 211/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8947 - loss: 0.3543
# Epoch 212/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8086 - loss: 0.3546
# Epoch 213/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8995 - loss: 0.3518
# Epoch 214/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8038 - loss: 0.3532
# Epoch 215/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8947 - loss: 0.3500
# Epoch 216/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8134 - loss: 0.3505
# Epoch 217/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8995 - loss: 0.3491
# Epoch 218/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8038 - loss: 0.3513
# Epoch 219/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8995 - loss: 0.3461
# Epoch 220/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8134 - loss: 0.3473
# Epoch 221/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8995 - loss: 0.3446
# Epoch 222/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8134 - loss: 0.3456
# Epoch 223/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9043 - loss: 0.3396
# Epoch 224/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8182 - loss: 0.3412
# Epoch 225/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9091 - loss: 0.3390
# Epoch 226/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8134 - loss: 0.3404
# Epoch 227/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9091 - loss: 0.3375
# Epoch 228/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8134 - loss: 0.3375
# Epoch 229/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9091 - loss: 0.3332
# Epoch 230/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8230 - loss: 0.3366
# Epoch 231/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9091 - loss: 0.3360
# Epoch 232/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8134 - loss: 0.3376
# Epoch 233/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9043 - loss: 0.3383
# Epoch 234/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8134 - loss: 0.3399
# Epoch 235/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9091 - loss: 0.3342
# Epoch 236/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8182 - loss: 0.3332
# Epoch 237/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9139 - loss: 0.3262
# Epoch 238/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8278 - loss: 0.3256
# Epoch 239/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9139 - loss: 0.3274
# Epoch 240/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8182 - loss: 0.3315
# Epoch 241/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9043 - loss: 0.3291
# Epoch 242/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8278 - loss: 0.3246
# Epoch 243/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9139 - loss: 0.3258
# Epoch 244/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8182 - loss: 0.3268
# Epoch 245/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9187 - loss: 0.3208
# Epoch 246/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8325 - loss: 0.3196
# Epoch 247/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9187 - loss: 0.3205
# Epoch 248/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8182 - loss: 0.3251
# Epoch 249/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9139 - loss: 0.3202
# Epoch 250/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8278 - loss: 0.3184
# Epoch 251/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9187 - loss: 0.3190
# Epoch 252/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8278 - loss: 0.3175
# Epoch 253/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9234 - loss: 0.3121
# Epoch 254/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8325 - loss: 0.3109
# Epoch 255/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9282 - loss: 0.3101
# Epoch 256/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8325 - loss: 0.3139
# Epoch 257/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9187 - loss: 0.3122
# Epoch 258/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8278 - loss: 0.3126
# Epoch 259/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9187 - loss: 0.3153
# Epoch 260/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8278 - loss: 0.3159
# Epoch 261/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9187 - loss: 0.3121
# Epoch 262/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8325 - loss: 0.3066
# Epoch 263/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9282 - loss: 0.3017
# Epoch 264/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8325 - loss: 0.3038
# Epoch 265/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9282 - loss: 0.3031
# Epoch 266/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8325 - loss: 0.3044
# Epoch 267/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9282 - loss: 0.3035
# Epoch 268/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8325 - loss: 0.3061
# Epoch 269/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9234 - loss: 0.3059
# Epoch 270/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8325 - loss: 0.3022
# Epoch 271/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9330 - loss: 0.3003
# Epoch 272/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.8325 - loss: 0.3006
# Epoch 273/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9330 - loss: 0.2990
# Epoch 274/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8325 - loss: 0.2988
# Epoch 275/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9378 - loss: 0.2957
# Epoch 276/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8325 - loss: 0.2981
# Epoch 277/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9282 - loss: 0.2993
# Epoch 278/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8325 - loss: 0.2979
# Epoch 279/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9378 - loss: 0.2965
# Epoch 280/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8325 - loss: 0.2966
# Epoch 281/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9282 - loss: 0.2943
# Epoch 282/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8421 - loss: 0.2921
# Epoch 283/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9426 - loss: 0.2895
# Epoch 284/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8469 - loss: 0.2883
# Epoch 285/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9378 - loss: 0.2866
# Epoch 286/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8421 - loss: 0.2856
# Epoch 287/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9426 - loss: 0.2836
# Epoch 288/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8517 - loss: 0.2834
# Epoch 289/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9426 - loss: 0.2833
# Epoch 290/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8421 - loss: 0.2831
# Epoch 291/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9426 - loss: 0.2835
# Epoch 292/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8373 - loss: 0.2839
# Epoch 293/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9426 - loss: 0.2825
# Epoch 294/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8421 - loss: 0.2810
# Epoch 295/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9426 - loss: 0.2803
# Epoch 296/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8708 - loss: 0.2782
# Epoch 297/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9426 - loss: 0.2761
# Epoch 298/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8708 - loss: 0.2753
# Epoch 299/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9426 - loss: 0.2748
# Epoch 300/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8708 - loss: 0.2753
# Epoch 301/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9426 - loss: 0.2750
# Epoch 302/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8708 - loss: 0.2725
# Epoch 303/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9474 - loss: 0.2708
# Epoch 304/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8804 - loss: 0.2702
# Epoch 305/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9426 - loss: 0.2697
# Epoch 306/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8756 - loss: 0.2696
# Epoch 307/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9474 - loss: 0.2705
# Epoch 308/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8708 - loss: 0.2706
# Epoch 309/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9426 - loss: 0.2716
# Epoch 310/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8660 - loss: 0.2704
# Epoch 311/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9426 - loss: 0.2699
# Epoch 312/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8708 - loss: 0.2692
# Epoch 313/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9426 - loss: 0.2701
# Epoch 314/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8804 - loss: 0.2672
# Epoch 315/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9474 - loss: 0.2634
# Epoch 316/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8852 - loss: 0.2632
# Epoch 317/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9474 - loss: 0.2607
# Epoch 318/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8947 - loss: 0.2602
# Epoch 319/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9474 - loss: 0.2611
# Epoch 320/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8852 - loss: 0.2612
# Epoch 321/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9474 - loss: 0.2601
# Epoch 322/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8947 - loss: 0.2583
# Epoch 323/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9474 - loss: 0.2561
# Epoch 324/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8900 - loss: 0.2561
# Epoch 325/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9474 - loss: 0.2549
# Epoch 326/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8947 - loss: 0.2548
# Epoch 327/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9474 - loss: 0.2548
# Epoch 328/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8900 - loss: 0.2567
# Epoch 329/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9474 - loss: 0.2570
# Epoch 330/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8947 - loss: 0.2543
# Epoch 331/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9474 - loss: 0.2531
# Epoch 332/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8900 - loss: 0.2527
# Epoch 333/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9474 - loss: 0.2501
# Epoch 334/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8947 - loss: 0.2509
# Epoch 335/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9474 - loss: 0.2508
# Epoch 336/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8995 - loss: 0.2507
# Epoch 337/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9474 - loss: 0.2511
# Epoch 338/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8995 - loss: 0.2472
# Epoch 339/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9474 - loss: 0.2438
# Epoch 340/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9234 - loss: 0.2431
# Epoch 341/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9474 - loss: 0.2429
# Epoch 342/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9187 - loss: 0.2409
# Epoch 343/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9474 - loss: 0.2396
# Epoch 344/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9234 - loss: 0.2409
# Epoch 345/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9474 - loss: 0.2429
# Epoch 346/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9043 - loss: 0.2430
# Epoch 347/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9474 - loss: 0.2455
# Epoch 348/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8947 - loss: 0.2465
# Epoch 349/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9474 - loss: 0.2436
# Epoch 350/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9043 - loss: 0.2414
# Epoch 351/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9474 - loss: 0.2389
# Epoch 352/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9187 - loss: 0.2390
# Epoch 353/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9474 - loss: 0.2393
# Epoch 354/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9139 - loss: 0.2403
# Epoch 355/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9474 - loss: 0.2417
# Epoch 356/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9091 - loss: 0.2411
# Epoch 357/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9474 - loss: 0.2401
# Epoch 358/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9091 - loss: 0.2394
# Epoch 359/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9474 - loss: 0.2386
# Epoch 360/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9139 - loss: 0.2375
# Epoch 361/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9474 - loss: 0.2351
# Epoch 362/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9282 - loss: 0.2327
# Epoch 363/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9474 - loss: 0.2296
# Epoch 364/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9234 - loss: 0.2282
# Epoch 365/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9474 - loss: 0.2294
# Epoch 366/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9282 - loss: 0.2292
# Epoch 367/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9474 - loss: 0.2284
# Epoch 368/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9330 - loss: 0.2270
# Epoch 369/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9474 - loss: 0.2263
# Epoch 370/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9378 - loss: 0.2247
# Epoch 371/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9522 - loss: 0.2244
# Epoch 372/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9330 - loss: 0.2228
# Epoch 373/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9474 - loss: 0.2228
# Epoch 374/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9426 - loss: 0.2207
# Epoch 375/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9522 - loss: 0.2180
# Epoch 376/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9378 - loss: 0.2187
# Epoch 377/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9522 - loss: 0.2199
# Epoch 378/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9426 - loss: 0.2176
# Epoch 379/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9569 - loss: 0.2168
# Epoch 380/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9426 - loss: 0.2137
# Epoch 381/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9522 - loss: 0.2157
# Epoch 382/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9426 - loss: 0.2148
# Epoch 383/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9569 - loss: 0.2128
# Epoch 384/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9426 - loss: 0.2133
# Epoch 385/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9522 - loss: 0.2138
# Epoch 386/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9426 - loss: 0.2128
# Epoch 387/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9569 - loss: 0.2134
# Epoch 388/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9426 - loss: 0.2129
# Epoch 389/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9522 - loss: 0.2125
# Epoch 390/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9426 - loss: 0.2106
# Epoch 391/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9569 - loss: 0.2109
# Epoch 392/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9426 - loss: 0.2103
# Epoch 393/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9569 - loss: 0.2109
# Epoch 394/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9426 - loss: 0.2079
# Epoch 395/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9569 - loss: 0.2054
# Epoch 396/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9426 - loss: 0.2031
# Epoch 397/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9569 - loss: 0.2042
# Epoch 398/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9426 - loss: 0.2059
# Epoch 399/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9569 - loss: 0.2051
# Epoch 400/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9426 - loss: 0.2022
# Epoch 401/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9617 - loss: 0.2024
# Epoch 402/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9426 - loss: 0.2004
# Epoch 403/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9617 - loss: 0.1999
# Epoch 404/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9426 - loss: 0.2004
# Epoch 405/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9617 - loss: 0.2013
# Epoch 406/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9426 - loss: 0.1997
# Epoch 407/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9569 - loss: 0.1981
# Epoch 408/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9474 - loss: 0.1982
# Epoch 409/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9665 - loss: 0.2011
# Epoch 410/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9426 - loss: 0.1988
# Epoch 411/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9617 - loss: 0.1954
# Epoch 412/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9474 - loss: 0.1921
# Epoch 413/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9617 - loss: 0.1920
# Epoch 414/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9474 - loss: 0.1916
# Epoch 415/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9617 - loss: 0.1926
# Epoch 416/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9474 - loss: 0.1917
# Epoch 417/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9617 - loss: 0.1918
# Epoch 418/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9474 - loss: 0.1920
# Epoch 419/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9665 - loss: 0.1933
# Epoch 420/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9426 - loss: 0.1931
# Epoch 421/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9617 - loss: 0.1938
# Epoch 422/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9474 - loss: 0.1939
# Epoch 423/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9665 - loss: 0.1956
# Epoch 424/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9426 - loss: 0.1938
# Epoch 425/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9617 - loss: 0.1938
# Epoch 426/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9426 - loss: 0.1933
# Epoch 427/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9665 - loss: 0.1916
# Epoch 428/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9426 - loss: 0.1891
# Epoch 429/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9713 - loss: 0.1873
# Epoch 430/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9474 - loss: 0.1855
# Epoch 431/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9713 - loss: 0.1833
# Epoch 432/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9522 - loss: 0.1811
# Epoch 433/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9713 - loss: 0.1803
# Epoch 434/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9522 - loss: 0.1815
# Epoch 435/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9713 - loss: 0.1857
# Epoch 436/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9522 - loss: 0.1831
# Epoch 437/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9713 - loss: 0.1822
# Epoch 438/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9522 - loss: 0.1799
# Epoch 439/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9713 - loss: 0.1809
# Epoch 440/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9522 - loss: 0.1789
# Epoch 441/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9713 - loss: 0.1770
# Epoch 442/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9522 - loss: 0.1769
# Epoch 443/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9713 - loss: 0.1794
# Epoch 444/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9522 - loss: 0.1783
# Epoch 445/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9713 - loss: 0.1789
# Epoch 446/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9522 - loss: 0.1778
# Epoch 447/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9713 - loss: 0.1793
# Epoch 448/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9522 - loss: 0.1779
# Epoch 449/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9713 - loss: 0.1778
# Epoch 450/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9522 - loss: 0.1735
# Epoch 451/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9713 - loss: 0.1722
# Epoch 452/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9522 - loss: 0.1724
# Epoch 453/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9713 - loss: 0.1716
# Epoch 454/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9522 - loss: 0.1691
# Epoch 455/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9713 - loss: 0.1716
# Epoch 456/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9522 - loss: 0.1726
# Epoch 457/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9713 - loss: 0.1740
# Epoch 458/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9522 - loss: 0.1714
# Epoch 459/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9761 - loss: 0.1715
# Epoch 460/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9522 - loss: 0.1685
# Epoch 461/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9761 - loss: 0.1675
# Epoch 462/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9522 - loss: 0.1647
# Epoch 463/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9761 - loss: 0.1642
# Epoch 464/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9522 - loss: 0.1624
# Epoch 465/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9761 - loss: 0.1638
# Epoch 466/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9522 - loss: 0.1628
# Epoch 467/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9761 - loss: 0.1645
# Epoch 468/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9522 - loss: 0.1639
# Epoch 469/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9761 - loss: 0.1661
# Epoch 470/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9522 - loss: 0.1660
# Epoch 471/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9761 - loss: 0.1687
# Epoch 472/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9522 - loss: 0.1666
# Epoch 473/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9761 - loss: 0.1652
# Epoch 474/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9522 - loss: 0.1613
# Epoch 475/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9761 - loss: 0.1601
# Epoch 476/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9569 - loss: 0.1597
# Epoch 477/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9761 - loss: 0.1622
# Epoch 478/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9569 - loss: 0.1604
# Epoch 479/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9761 - loss: 0.1591
# Epoch 480/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9522 - loss: 0.1588
# Epoch 481/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9761 - loss: 0.1603
# Epoch 482/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9569 - loss: 0.1579
# Epoch 483/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9809 - loss: 0.1570
# Epoch 484/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9522 - loss: 0.1566
# Epoch 485/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9761 - loss: 0.1586
# Epoch 486/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9569 - loss: 0.1568
# Epoch 487/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9809 - loss: 0.1566
# Epoch 488/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9569 - loss: 0.1545
# Epoch 489/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9761 - loss: 0.1543
# Epoch 490/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9713 - loss: 0.1520
# Epoch 491/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9856 - loss: 0.1511
# Epoch 492/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9713 - loss: 0.1498
# Epoch 493/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9809 - loss: 0.1511
# Epoch 494/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9713 - loss: 0.1501
# Epoch 495/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9809 - loss: 0.1517
# Epoch 496/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9665 - loss: 0.1508
# Epoch 497/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9761 - loss: 0.1537
# Epoch 498/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9617 - loss: 0.1528
# Epoch 499/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9809 - loss: 0.1520
# Epoch 500/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9713 - loss: 0.1494
# Epoch 501/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9809 - loss: 0.1510
# Epoch 502/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9713 - loss: 0.1488
# Epoch 503/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9856 - loss: 0.1473
# Epoch 504/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9713 - loss: 0.1447
# Epoch 505/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9856 - loss: 0.1466
# Epoch 506/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9713 - loss: 0.1455
# Epoch 507/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9856 - loss: 0.1456
# Epoch 508/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9713 - loss: 0.1450
# Epoch 509/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9856 - loss: 0.1465
# Epoch 510/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9713 - loss: 0.1455
# Epoch 511/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9809 - loss: 0.1458
# Epoch 512/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9713 - loss: 0.1444
# Epoch 513/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9856 - loss: 0.1457
# Epoch 514/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9761 - loss: 0.1430
# Epoch 515/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9856 - loss: 0.1414
# Epoch 516/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9809 - loss: 0.1404
# Epoch 517/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9856 - loss: 0.1408
# Epoch 518/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9809 - loss: 0.1393
# Epoch 519/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9856 - loss: 0.1389
# Epoch 520/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9809 - loss: 0.1365
# Epoch 521/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9856 - loss: 0.1366
# Epoch 522/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9809 - loss: 0.1360
# Epoch 523/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9856 - loss: 0.1369
# Epoch 524/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9809 - loss: 0.1367
# Epoch 525/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9856 - loss: 0.1392
# Epoch 526/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9809 - loss: 0.1371
# Epoch 527/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9856 - loss: 0.1372
# Epoch 528/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9809 - loss: 0.1351
# Epoch 529/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9856 - loss: 0.1367
# Epoch 530/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9809 - loss: 0.1343
# Epoch 531/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9856 - loss: 0.1342
# Epoch 532/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9856 - loss: 0.1323
# Epoch 533/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9856 - loss: 0.1326
# Epoch 534/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9856 - loss: 0.1315
# Epoch 535/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9856 - loss: 0.1334
# Epoch 536/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9809 - loss: 0.1325
# Epoch 537/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9856 - loss: 0.1336
# Epoch 538/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9856 - loss: 0.1316
# Epoch 539/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9856 - loss: 0.1326
# Epoch 540/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9809 - loss: 0.1311
# Epoch 541/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9856 - loss: 0.1312
# Epoch 542/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9856 - loss: 0.1277
# Epoch 543/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9856 - loss: 0.1278
# Epoch 544/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9856 - loss: 0.1272
# Epoch 545/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9856 - loss: 0.1280
# Epoch 546/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9856 - loss: 0.1264
# Epoch 547/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9856 - loss: 0.1269
# Epoch 548/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9856 - loss: 0.1259
# Epoch 549/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9856 - loss: 0.1272
# Epoch 550/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9856 - loss: 0.1258
# Epoch 551/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9856 - loss: 0.1272
# Epoch 552/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9856 - loss: 0.1258
# Epoch 553/1000
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0584
# Epoch 818/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0583
# Epoch 819/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0581
# Epoch 820/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0578
# Epoch 821/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0575
# Epoch 822/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.0574
# Epoch 823/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0573
# Epoch 824/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0572
# Epoch 825/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0570
# Epoch 826/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0569
# Epoch 827/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0569
# Epoch 828/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0567
# Epoch 829/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0566
# Epoch 830/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0566
# Epoch 831/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0565
# Epoch 832/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0564
# Epoch 833/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0563
# Epoch 834/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0561
# Epoch 835/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0561
# Epoch 836/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0559
# Epoch 837/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0558
# Epoch 838/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0557
# Epoch 839/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0556
# Epoch 840/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0555
# Epoch 841/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 1.0000 - loss: 0.0554
# Epoch 842/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0553
# Epoch 843/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0553
# Epoch 844/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0551
# Epoch 845/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0550
# Epoch 846/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0549
# Epoch 847/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0549
# Epoch 848/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0548
# Epoch 849/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0547
# Epoch 850/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0546
# Epoch 851/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0546
# Epoch 852/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0545
# Epoch 853/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0544
# Epoch 854/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 1.0000 - loss: 0.0543
# Epoch 855/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0543
# Epoch 856/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0540
# Epoch 857/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0539
# Epoch 858/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0537
# Epoch 859/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0537
# Epoch 860/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0535
# Epoch 861/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0532
# Epoch 862/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 0.0530
# Epoch 863/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0530
# Epoch 864/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0527
# Epoch 865/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0526
# Epoch 866/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0525
# Epoch 867/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0523
# Epoch 868/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0523
# Epoch 869/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0522
# Epoch 870/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0521
# Epoch 871/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0520
# Epoch 872/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0519
# Epoch 873/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0518
# Epoch 874/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0517
# Epoch 875/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0517
# Epoch 876/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0515
# Epoch 877/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0515
# Epoch 878/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0514
# Epoch 879/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0514
# Epoch 880/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0513
# Epoch 881/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0512
# Epoch 882/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0511
# Epoch 883/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0510
# Epoch 884/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0509
# Epoch 885/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0509
# Epoch 886/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0507
# Epoch 887/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0506
# Epoch 888/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0505
# Epoch 889/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0504
# Epoch 890/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0502
# Epoch 891/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0501
# Epoch 892/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0500
# Epoch 893/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0499
# Epoch 894/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0497
# Epoch 895/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0497
# Epoch 896/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0496
# Epoch 897/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0496
# Epoch 898/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0495
# Epoch 899/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0494
# Epoch 900/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0493
# Epoch 901/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0493
# Epoch 902/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0492
# Epoch 903/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0491
# Epoch 904/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0491
# Epoch 905/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0490
# Epoch 906/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0489
# Epoch 907/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0488
# Epoch 908/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0487
# Epoch 909/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0486
# Epoch 910/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0484
# Epoch 911/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0483
# Epoch 912/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 1.0000 - loss: 0.0482
# Epoch 913/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0482
# Epoch 914/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0480
# Epoch 915/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0480
# Epoch 916/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0478
# Epoch 917/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0478
# Epoch 918/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0477
# Epoch 919/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0476
# Epoch 920/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0475
# Epoch 921/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0475
# Epoch 922/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0473
# Epoch 923/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0472
# Epoch 924/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0472
# Epoch 925/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0471
# Epoch 926/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0469
# Epoch 927/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0469
# Epoch 928/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 0.0467
# Epoch 929/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0467
# Epoch 930/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0465
# Epoch 931/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0464
# Epoch 932/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0463
# Epoch 933/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0462
# Epoch 934/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0461
# Epoch 935/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0460
# Epoch 936/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0459
# Epoch 937/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0459
# Epoch 938/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0458
# Epoch 939/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0457
# Epoch 940/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0456
# Epoch 941/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0456
# Epoch 942/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0455
# Epoch 943/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 0.0455
# Epoch 944/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 1.0000 - loss: 0.0454
# Epoch 945/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0453
# Epoch 946/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0453
# Epoch 947/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0453
# Epoch 948/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0452
# Epoch 949/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0451
# Epoch 950/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0451
# Epoch 951/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0450
# Epoch 952/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0449
# Epoch 953/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0448
# Epoch 954/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0447
# Epoch 955/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0446
# Epoch 956/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0445
# Epoch 957/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0445
# Epoch 958/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0444
# Epoch 959/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0443
# Epoch 960/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0441
# Epoch 961/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0440
# Epoch 962/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0439
# Epoch 963/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0438
# Epoch 964/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.0437
# Epoch 965/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0436
# Epoch 966/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0435
# Epoch 967/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0435
# Epoch 968/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0434
# Epoch 969/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0433
# Epoch 970/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0432
# Epoch 971/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0432
# Epoch 972/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0431
# Epoch 973/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0430
# Epoch 974/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0430
# Epoch 975/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 1.0000 - loss: 0.0430
# Epoch 976/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0429
# Epoch 977/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0429
# Epoch 978/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0428
# Epoch 979/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.0428
# Epoch 980/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0427
# Epoch 981/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0427
# Epoch 982/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0426
# Epoch 983/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0426
# Epoch 984/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0425
# Epoch 985/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0425
# Epoch 986/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0423
# Epoch 987/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0423
# Epoch 988/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0421
# Epoch 989/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0421
# Epoch 990/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0419
# Epoch 991/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0419
# Epoch 992/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0418
# Epoch 993/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0417
# Epoch 994/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0415
# Epoch 995/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0415
# Epoch 996/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0414
# Epoch 997/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0413
# Epoch 998/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0412
# Epoch 999/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0411
# Epoch 1000/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0410

# %%
# Vamos verificar quais variáveis foram salvas no processo de treinamento
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['accuracy', 'loss'])

# %% [markdown]
# ### 4.3 - Visualização do resultado do treinamento
#
# Para sabermos como o treinamento foi realizado precisamos visualizar a função de custo e a métrica ao longo do processo de treinamento.
#
# ### Exercício #7:
#
# Implemente na célula abaixo a visualização dos resultados do treinamento. Observe que os valores da função de custo e da métrico estão no dicionário history com nomes `'loss'` e `'acc'`. Mas estes nomes podem variar, de acordo com a forma que os parâmetros foram definidos. Verifique a variável history_dict history_dict.keys() para conferir os nomes corretos.
#
# Consulte as notas de aula para relembrar como fazer os gráficos da função de custo e da métrica em função do número de épocas.

# %%
# PARA VOCÊ FAZER: visualização do resultado do treinamento

# Salva custo e exatidão em vetores
### COMECE AQUI ### (≈ 2 linhas)
custo = history_dict['loss'] 
exatidao = history_dict['accuracy'] 
### TERMINE AQUI ###

# Cria vetor de épocas
### COMECE AQUI ### (≈ 1 linha)
epocas = range(1, len(custo) + 1) 
### TERMINE AQUI ###

# Gráfico do custo em funçaõ das épocas
### COMECE AQUI ### (≈ 5 linhas)
plt.plot(epocas, custo, 'b', label='Custo')
plt.title('Valor da função de custo')
plt.xlabel('Épocas')
plt.ylabel('Custo')
plt.legend()
### TERMINE AQUI ###

# Gráfico da exatidão em função das épocas
### COMECE AQUI ### (≈ 5 linhas)
plt.plot(epocas, exatidao, 'r', label='Exatidão')
plt.title('Valor da exatidão')
plt.xlabel('Épocas')
plt.ylabel('Exatidão')
plt.legend()
plt.show()
### TERMINE AQUI ###

# %% [markdown]
# **Saída esperada:**
#
# O comportamento esperado para a função de custo durante o treinamento é ela decrescer monotomicamente do início até o final. Para a exatidão, o comportamento esperado é ela aumentar durante o treinamento, apresentando algumas oscilações e alcançando um valor alto no final.
#
# Se você obteve esses resultados, então, a sua rede foi treinada de forma satisfatória e pode-se concluir que ela tem uma capacidade alta para se ajustar aos dados de treinamento.

# %% [markdown]
# ### 4.4 - Avaliação do desempenho da rede neural ###
#
# Após treinar a RNA é importante avaliar o seu desempenho com dados que não foram  utilizados no treinamento. Para isso usamos o dados de teste, que estão nos tensores test_set_x e test_set_y.
#
# ### Exercício #8:
#
# Avalie a sua rede neural calculando os valores da função de custo e da exatidão para os dados de teste usando o método evaluate. Calcule esses valores também para os dados de treinamento para poder fazer comparação.

# %%
# PARA VOCÊ FAZER: calculo do custo e exatidão para os dados de teste

# Usando método evaluate calcule o custo e a exatidão para os dados de treinamento e depois apresente os resultados
### COMECE AQUI ### (≈ 1 linha)
custo_e_metricas_train = rna.evaluate(train_set_x, train_set_y)
### TERMINE AQUI ###
print(custo_e_metricas_train)

# Usando método evaluate calcule o custo e a exatidão para os dados de teste e depois apresente os resultados
### COMECE AQUI ### (≈ 1 linha)
custo_e_metricas_test = rna.evaluate(test_set_x, test_set_y)
### TERMINE AQUI ###
print(custo_e_metricas_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 0.0408
# [0.040934789925813675, 1.0]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7804 - loss: 0.7019
# [0.6785804629325867, 0.7799999713897705]

# %% [markdown]
# **Resultados esperados:**
#
#     209/209 [==============================] - 0s 656us/sample - loss: 0.3270 - acc: 0.9091
#     [0.3269858589868226, 0.90909094]
#     50/50 [==============================] - 0s 260us/sample - loss: 0.5960 - acc: 0.7000
#     [0.5959848165512085, 0.7]
#
# **Comentários:**
#
# - A exatidação obtida com os dados de treinamento é cerca de 90%, isso significa que a sua rede é satisfatória para resolver esse problema.
#
# - A exatidão obtida com os dados de teste é de cerca de 68%. Esse resultado de fato não é muito bom para essa tarefa simples de classificação.
#
# Analisando esses dados surge uma dúvida. Porque a rede não foi capaz de apresentar um bom desempenho nos dados de teste, se os resultados foram bons nos dados de treinamento?

# %% [markdown]
# ### Exercício #9:
#
# Para avaliar melhor o desepenho da sua rede calcule as saídas previstas dos exemplos do conjunto de teste usando o método predict e a função numpy round faça um gráfico com as classes reais e previstas dos dados do conjunto de teste. Se não souber como fazer consulte as notas de aula e o notebook que desenvolvemos.

# %%
# PARA VOCÊ FAZER: calculo das classes previstas dos dados de teste

# Usando método predict calcule as classes previstas
### COMECE AQUI ### (≈ 2 linhas)
yy_prev = rna.predict(test_set_x)
### TERMINE AQUI ###

# Transforma saida prevista em números inteiros
yy_prev = np.round(yy_prev).astype(int)

# Gráfico das classes reais e previstas
plt.plot(test_set_y, 'ro', label='Real')
plt.plot(yy_prev, 'bo', label='Previsto')
### TERMINE AQUI ###
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
plt.figure(figsize=(20, 15))
for i in range(m_test):
    plt.subplot(5, 10, i+1)
    plt.imshow(test_set_x_orig[i])
    plt.axis('off')
    plt.title(f"Real: {classes[test_set_y[i][0]].decode('utf-8')}\nPrevisto: {classes[yy_prev[i][0]].decode('utf-8')}")
plt.show()

# %% [markdown]
# **Saída esperada:**
#
# Veja a imagem classes_previstas_test.png fornecida com o material do trabalho

# %% [markdown]
# **Comentários:**
#
# - Uma previsão errada de classe pode ser dectada pelos círculos vermelhos, pois quando a classe prevista é igual à classe real o círculo azul é colocado em cima do vermelho tapando-o.
#
# - Provavelmente no grafico devem aparecer mais círculos azuis do que vermelhos indicando que existem mais acertos do que erros na previsão das classes.

# %% [markdown]
# Use o código a seguir, mudando a variável 'index', para você visualizar as imagens e a classe prevista dos exemplos de teste.

# %%
# Exemplo de classificação de uma imagem.
index = 6
plt.imshow(test_set_x[index,:].reshape((num_px, num_px, 3)))
print ("y = " + str(test_set_y[index]) + ", imagem é prevista como sendo uma '" + classes[np.squeeze(yy_prev[index])].decode("utf-8"))
# Out:
# y = [1], imagem é prevista como sendo uma 'non-cat

# %% [markdown]
# **Interpretação dos resultados:**
#
# O custo decrescendo durante o treinamento mostra que os parâmetros estão sendo ajustados de forma a que a rede está aprendendo os dados de treinamento. Como o custo obtido não é muito baixo, então, provavelmente é possível treinar ainda mais a rede para obter melhores resultados nos dados de treinamento.
#
# Tente refazer as etapas 4.2, 4.3 e 4.4, aumentando o número de épocas para algo em torno de 5000, para retreinar a rede. Você verá que o custo de treinamento diminui até praticamente zero e a exatidão aumenta para quase 100%.
#
# **Importante:** só tente treinar com mais épocas após entregar o seu trabalho, pois os resultados esperados são para o treinamento com 1000 épocas.
#
# Contudo, nem sempre é bom treinar a rede até se obter custo perto de zero e exatidão 100% para os dados de treinamento. Em geral quando isso acontece o custo e a exatidão para os dados de teste pioraram. Nesse caso, pode ocorrer que a rede está memorizando os dados de treinamento e não generalizando a solução do problema. Veremos daqui algumas aulas como resolver esse problema. Mas podemos verificar esse fato retreinando a rede para um número maior de épocas.

# %% [markdown]
# ## 5 - Desenvolvimento e teste da rede neural deep-learning ##
#
# Nessa etapa do trabalho você vai configurar, treinar e testar uma rede neural deep learning.
#
# ### Exercício #10:
#
# Usando o Keras configure e crie uma rede neural com as seguintes caracteríticas:
#
# - três camadas intermediárias com função de ativação tipo ReLu;
# - número de neurônios das camadas intermediárias: 64, 32, 16;
# - camada de saída deve possuir um único neurônio e ter função de ativação sigmóide.
#
# Essa rede deve ser criada dentro de uma função (build_model) e os argumentos dessa função são: a dimensão dos dados de entrada e os números de neurônios das diversas camadas.

# %%
# PARA VOCÊ FAZER: configuração da rede deep-learning

# Importar do Keras modelos e camadas
from tensorflow.keras import models
from tensorflow.keras import layers

def build_model(data_shape,n1,n2,n3,n4):
    """
    Essa função configura uma rede neural deep-learnig
    
    Argumentos:
    data_shape = tuple com dimensões dos dados de entrada da rede
    n1 = número de neurônios da primeira camada
    n2 = número de neurônios da segunda camada
    n3 = número de neurônios da terceira camada
    n4 = número de neurônios da camada de saída
        
    Retorna: modelo da rede neural
    """
    
    np.random.seed(3)
    
    model = models.Sequential()
    
    # Adicione as camadas em seu modelo de RNA
    #### COMECE AQUI ### (≈ 4 linhas)
    model.add(layers.Dense(n1, input_shape=data_shape, activation='relu'))
    model.add(layers.Dense(n2, activation='relu'))
    model.add(layers.Dense(n3, activation='relu'))
    model.add(layers.Dense(n4, activation='sigmoid'))
    ### TERMINE AQUI ###
    
    return model

# Redefine semente para geração de números aleatórios
np.random.seed(3)

# Dimensão dos dados de entrada
data_shape = (12288,)

# Definição dos números de neurônios das camadas
#### COMECE AQUI ### (≈ 4 linhas)
n1 = 64
n2 = 32
n3 = 16
n4 = 1
### TERMINE AQUI ###

# Cria rede neural deep learning
#### COMECE AQUI ### (≈ 1 linha)
rnadl = build_model(data_shape,n1,n2,n3,n4)
### TERMINE AQUI ###
rnadl.summary()
# Out:
# /home/codespace/.local/share/virtualenvs/T2_Classificação_binaria_keras-L9rped1J/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_16 (Dense)                │ (None, 64)             │       786,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 789,121 (3.01 MB)
#  Trainable params: 789,121 (3.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Saída esperada:**
#
#     Model: "sequential_1"
#     _________________________________________________________________
#     Layer (type)                 Output Shape              Param #
#     =================================================================
#     dense_2 (Dense)              (None, 64)                786496
#     _________________________________________________________________
#     dense_3 (Dense)              (None, 32)                2080
#     _________________________________________________________________
#     dense_4 (Dense)              (None, 16)                528
#     _________________________________________________________________
#     dense_5 (Dense)              (None, 1)                 17
#     =================================================================
#     Total params: 789,121
#     Trainable params: 789,121
#     Non-trainable params: 0
#     _________________________________________________________________

# %% [markdown]
# ### Exercício #11:
#
# Repita os itens 4.2, 4.3 e 4.4 para a rede neural deep-learning. Use `rnadl` como nome da rede e acrescentando as letras `dl` nas variáveis de custo, exatidao e epocas.
#
# Na célula abaixo compile e treine a sua rede deep-learning para 10 épocas. Esse treinamento é só para verificar se o programa está correto.

# %%
# PARA VOCÊ FAZER: compilação e treinamento da rede deep-learning

# Compilação da rede 
### COMECE AQUI ### (≈ 2 linhas)
rnadl.compile(optimizer='adam', loss='binary_crossentropy', metrics=['f1_score'])
### TERMINE AQUI ###

# Teste de treinamento da rede
### COMECE AQUI ### (≈ 1 linha)
history = rnadl.fit(train_set_x, train_set_y, epochs=10)
### TERMINE AQUI ###
# Out:
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - f1_score: 0.5311 - loss: 0.8615
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - f1_score: 0.5068 - loss: 0.6805
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - f1_score: 0.5539 - loss: 0.6066
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - f1_score: 0.4587 - loss: 0.5588
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - f1_score: 0.4706 - loss: 0.7475
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - f1_score: 0.5368 - loss: 0.6942
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - f1_score: 0.5197 - loss: 0.5803
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - f1_score: 0.5462 - loss: 0.6192
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - f1_score: 0.5289 - loss: 0.5964
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - f1_score: 0.5347 - loss: 0.5518

# %% [markdown]
# **Saída esparada:**
#
#     Epoch 1/10
#     209/209 [==============================] - 0s 1ms/sample - loss: 0.7339 - acc: 0.3206
#     Epoch 2/10
#     209/209 [==============================] - 0s 175us/sample - loss: 0.6939 - acc: 0.5072
#     Epoch 3/10
#     209/209 [==============================] - 0s 172us/sample - loss: 0.6786 - acc: 0.5933
#     Epoch 4/10
#     209/209 [==============================] - 0s 191us/sample - loss: 0.6661 - acc: 0.6268
#     Epoch 5/10
#     209/209 [==============================] - 0s 177us/sample - loss: 0.6588 - acc: 0.6316
#     Epoch 6/10
#     209/209 [==============================] - 0s 167us/sample - loss: 0.6529 - acc: 0.6459
#     Epoch 7/10
#     209/209 [==============================] - 0s 162us/sample - loss: 0.6479 - acc: 0.6507
#     Epoch 8/10
#     209/209 [==============================] - 0s 172us/sample - loss: 0.6433 - acc: 0.6507
#     Epoch 9/10
#     209/209 [==============================] - 0s 167us/sample - loss: 0.6391 - acc: 0.6555
#     Epoch 10/10
#     209/209 [==============================] - 0s 167us/sample - loss: 0.6359 - acc: 0.6555

# %% [markdown]
# Na célula abaixo treine a sua rede deep-learning por 1000 épocas. Use verbose = 0 e batch_size = 209.

# %%
# PARA VOCÊ FAZER: treinamento da rede deep-learning por 1000 épocas

### COMECE AQUI ### (≈ 1 linha)
historydl = rnadl.fit(train_set_x, train_set_y, epochs=1000, verbose=0)
### TERMINE AQUI ###

# Vamos verificar quais variáveis foram salvas no processo de treinamento
historydl_dict = historydl.history
historydl_dict.keys()
# Out:
# dict_keys(['f1_score', 'loss'])

# %% [markdown]
# ### Exercício #12:
#
# Na célula abaixo introduza os comandos para visualizar os resultados da sua rede deep-learning.

# %%
# PARA VOCÊ FAZER: visualização do resultado do treinamento da rede deep-learning

# Salva custo e exatidão em vetores
### COMECE AQUI ### (≈ 2 linhas)
custodl = historydl_dict['loss']
exatidaodl = historydl_dict['f1_score']
### TERMINE AQUI ###

# Cria vetor de épocas
### COMECE AQUI ### (≈ 1 linha)
epocasdl = range(1, len(custodl) + 1)
### TERMINE AQUI ###

# Gráfico do custo em funçaõ das épocas
### COMECE AQUI ### (≈ 5 linhas)
plt.plot(epocasdl, custodl, 'r', label='Custo')
plt.title('Valor da função de custo')
plt.xlabel('Épocas')
plt.ylabel('Custo')
plt.legend()
### TERMINE AQUI ###

# Gráfico da exatidão em função das épocas
### COMECE AQUI ### (≈ 5 linhas)
plt.plot(epocasdl, exatidaodl, 'b', label='F1')
plt.title('Valor do F1')
plt.xlabel('Épocas')
plt.ylabel('F1')
plt.legend()
### TERMINE AQUI ###

# %% [markdown]
# ### Exercício #13:
#
# Na célula abaixo introduza os comandos para avaliar a sua rede deep-learning para os dados de treinamento e de teste.

# %%
# PARA VOCÊ FAZER: calculo do custo e exatidão para os dados de treinamento e de teste para a rede deep-learning

# Usando método evaluate calcule o custo e a exatidão dos dados de treinamento e depois apresente os resultados
### COMECE AQUI ### (≈ 1 linha)
custo_e_metricasdl_train = rnadl.evaluate(train_set_x, train_set_y)
### TERMINE AQUI ###
print(custo_e_metricasdl_train)

# Usando método evaluate calcule o custo e a exatidão dos dados de teste e depois apresente os resultados
### COMECE AQUI ### (≈ 1 linha)
custo_e_metricasdl_test = rnadl.evaluate(test_set_x, test_set_y)
### TERMINE AQUI ###
print(custo_e_metricasdl_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - f1_score: 0.8040 - loss: 1.0148e-07
# [1.2372407809380093e-07, 0.8089887499809265]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - f1_score: 0.8851 - loss: 4.9198
# [4.647476673126221, 0.8767123222351074]

# %% [markdown]
# **Saída esperada:**
#
#     209/209 [==============================] - 0s 482us/sample - loss: 0.0115 - acc: 1.0000
#     [0.011545336649320913, 1.0]
#     50/50 [==============================] - 0s 399us/sample - loss: 1.0013 - acc: 0.7400
#     [1.0013008093833924, 0.74]

# %% [markdown]
# ### Exercício #14:
#
# Na célula abaixo introduza os comandos para clcular as classes previstas para os dados de teste.

# %%
# PARA VOCÊ FAZER: calculo das classes previstas dos dados de teste para a rede deep-learning

# Usando método predict calcule as classes previstas
### COMECE AQUI ### (≈ 2 linhas)
yy_prevdl = rnadl.predict(test_set_x)
### TERMINE AQUI ###

# Transforma saida prevista em números inteiros
yy_prevdl = np.round(yy_prevdl).astype(int)

# Gráfico das classes reais e previstas
### COMECE AQUI ### (≈ 7 linhas)
plt.plot(test_set_y, 'ro', label='Real')
plt.plot(yy_prevdl, 'bo', label='Previsto')
### TERMINE AQUI ###
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
plt.figure(figsize=(20, 15))
for i in range(m_test):
    plt.subplot(5, 10, i+1)
    plt.imshow(test_set_x_orig[i])
    plt.axis('off')
    plt.title(f"Real: {classes[test_set_y[i][0]].decode('utf-8')}\nPrevisto: {classes[yy_prevdl[i][0]].decode('utf-8')}")

# %% [markdown]
# **Saída esperada:**
#
# O número de erros de classificação é igual a 12 (ou 13), representado por 12 (13) bolinhas vermelhas, o que significa 76% (74%) dos 50 exemplos de teste.
#
# **Interpretação dos resultados:**
#
# Se você fez tudo correto, então, os resultados obtidos do custo e da exatidão para os dados de teste são melhores para a rede neural deep-learning do que para a rede neural rasa, como era de se esperar.
#
# Observe que a rede deep learning possui quase o mesmo número de parâmetros do que a rede rasa, mas obtém resultados mais satisfatórios.
#
# O que fez com que os resultados da rede deep learning fossem muito melhores do que a rede rasa? O número de camadas, o tipo de função de ativação, ou simplesmenete o número de parâmetros?

# %% [markdown]
# <font color='blue'>
#
# **O que é importante lembrar:**
# - A escolha do número de neurônios das camadas da rede é muito importane
# - O tipo de função de ativação usada pode fazer diferença nos resultados
# - Não é uma tarefa fácil desenvolver uma rede neural que apresenta um desempenho bom, mas não é impossível

# %% [markdown]
# ## 6 - Teste as redes que você desenvolveu com sua própria imagem (exercício opcional) ##
#
# Você pode usar qualquer imagem e verificar se as suas redes neurais são eficientes. Para fazer isso faça:
#     1. Clique em "File" na parte superior desse notebook e depois clique "Open" para ir para o seu diretório.
#     2. Adicione a sua imagem nesse diretório.
#     3. Troque o nome do arquivo onde se encontra a imagem no código abaixo.
#     4. Execute o código e verifique se a rede acerta (1 = imagem mostra gato, 0 = imagem não tem gato)!

# %%
# PARA VOCÊ FAZER: teste da rede com suas imagens

## COMECE AQUI ## (coloque o nome do arquivo com a sua imagem) 
#my_image = 
## TERMINE AQUI ##

# Pré-processamento da imagem para acertar dimensões.
fname = my_image
image = Image.open(fname)
my_image = image.resize((num_px, num_px), Image.ANTIALIAS)
my_image = np.array(my_image)
my_image = my_image.reshape((1, num_px*num_px*3))
my_image = my_image.astype(float)

# Previsão da rede neural
y_prev_myimage = rnadl.predict(my_image)
my_predicted_image = np.round(y_prev_myimage)
my_predicted_image = my_predicted_image.astype(int)

plt.imshow(image)
print("y = " + str(np.squeeze(my_predicted_image)) + ", sua rede prevê \"" + classes[int(np.squeeze(my_predicted_image)),].decode("utf-8") +  "\" picture.")

# %% [markdown]
# Finalmente, como sugestão, tente fazer alterações de parâmetros e executar o notebook novamente. Mas lembre-se de salvar o seu trabalho em um arquivo pdf e enviar para avaliação antes de modificar o notebook e realizar os seus testes.
#
# Algumas sugestões do que alterar:
#
# - Número de camadas;
# - Número de neurônios nas camadas;
# - Funções de ativação;
# - Tente impor um taxa de aprendizado;
# - Tente outras formas de normalizar os dados.
