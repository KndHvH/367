# %%
# !pip install opencv-python
# !pip install seaborn
# !pip install numpy
# Out:
# Requirement already satisfied: opencv-python in c:\users\mathe\pycharmprojects\matias\venv\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\mathe\pycharmprojects\matias\venv\lib\site-packages (from opencv-python) (1.23.1)
# WARNING: You are using pip version 21.3.1; however, version 22.2.1 is available.
# You should consider upgrading via the 'C:\Users\mathe\PycharmProjects\Matias\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: seaborn in c:\users\mathe\pycharmprojects\matias\venv\lib\site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\mathe\pycharmprojects\matias\venv\lib\site-packages (from seaborn) (1.23.1)
# Requirement already satisfied: scipy>=1.0 in c:\users\mathe\pycharmprojects\matias\venv\lib\site-packages (from seaborn) (1.9.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\mathe\pycharmprojects\matias\venv\lib\site-packages (from seaborn) (1.4.3)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\mathe\pycharmprojects\matias\venv\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\mathe\pycharmprojects\matias\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mathe\pycharmprojects\matias\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mathe\pycharmprojects\matias\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mathe\pycharmprojects\matias\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mathe\pycharmprojects\matias\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mathe\pycharmprojects\matias\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (4.34.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\mathe\pycharmprojects\matias\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mathe\pycharmprojects\matias\venv\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\mathe\pycharmprojects\matias\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# WARNING: You are using pip version 21.3.1; however, version 22.2.1 is available.
# You should consider upgrading via the 'C:\Users\mathe\PycharmProjects\Matias\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: numpy in c:\users\mathe\pycharmprojects\matias\venv\lib\site-packages (1.23.1)
# WARNING: You are using pip version 21.3.1; however, version 22.2.1 is available.
# You should consider upgrading via the 'C:\Users\mathe\PycharmProjects\Matias\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import seaborn as sns
import cv2
import numpy as np
img = cv2.imread('flor.png') #lê a imagem


import matplotlib.pyplot as plt #carrega o matplotlib
plt.imshow(img)
plt.axis('off');

#converte padrão BGR para RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
#separa as cores RGB
r = img.copy()
r = r[:, :, 0]
g = img.copy()
g = g[:, :, 1]
b = img.copy()
b = b[:, :, 2]

#imprime as cores separadamente
plt.imshow(b,cmap='Blues_r');
plt.imshow(r,cmap='Reds_r');
plt.imshow(g,cmap='Greens_r');

sns.distplot(img.flatten())  #imprime o histograma usando o seaborn
plt.xlim([0,256])
# Out:
# C:\Users\mathe\PycharmProjects\Matias\venv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (0.0, 256.0)

# %%
#histograma separado por cor

sns.kdeplot(r.flatten(),color='red',bw=0.005)
sns.kdeplot(g.flatten(),color='green',bw=0.005)
sns.kdeplot(b.flatten(),color='blue',bw=0.005)
plt.xlim([0,256])

#convolucionando
kernel = np.array([[0 , -1,  0],
                   [-1,  5, -1],
                   [0 , -1,  0]])

opencvSaida= cv2.filter2D(img, -1, kernel)
# Out:
# C:\Users\mathe\PycharmProjects\Matias\venv\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.005 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\mathe\PycharmProjects\Matias\venv\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.005 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\mathe\PycharmProjects\Matias\venv\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.005 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %%
#outros kernels

kernel = np.array([[-1, -1, -1],
                   [-1,  8, -1],
                   [-1, -1, -1]])


kernel = np.array([[ 1,  1,  1],
                   [ 0,  0,  0],
                   [-1, -1, -1]])
opencvSaida = cv2.filter2D(img, -1, kernel)
